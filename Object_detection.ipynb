# %% [markdown]
# <a href="https://colab.research.google.com/github/Kunj-7007/AI_ML_Workshop_LDRP/blob/Day4/Object_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Instal YOLO
# !pip -q install ultralytics

# %%
# Loada model and run detection
from ultralytics import YOLO
model = YOLO('yolov8n.pt')
results = model("/content/vegetables.jpg")
# Out:
# image 1/1 /content/vegetables.jpg: 640x384 1 apple, 2 broccolis, 2 carrots, 165.1ms
# Speed: 3.7ms preprocess, 165.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)

# %%
# Show result
results[0].show()
# Out:
# <PIL.Image.Image image mode=RGB size=736x1308>
